# %% [markdown]
# # Question 2 NYT
# - Data collect & store
# - Analysis I
# - Analysis II
# - Analysis III

# %% [markdown]
# # Data process and store

# %%
import  requests

# %% [markdown]
# # Archive API

# %%
#export nyt_archive_key="$3106eb1daa574677845dd5391133c916"
#such environ var expires when the bash is closed
import os
nyt_archive_key = os.environ.get('nyt_archive_key')
print(nyt_archive_key)
# Out:
# None

# %%
#http://api.nytimes.com/svc/archive/v1/2016/11.json?api-key={your-api-key}
#1.the key ?
#2.whats the download limitation？
#3.is every day's file needed ?
#4.any suggestions on what to analysize?
nyt_archive_key = "3106eb1daa574677845dd5391133c916"
#r = requests.get("http://api.nytimes.com/svc/archive/v1/2016/11.json?api-key=" + nyt_archive_key)

# %%
r.json()
print(1)

# %%
import json
json.dumps(r.json())             # {"job": ["dev", "mgr"], "name": {"last": "Smith", "first": "Bob"}, "age": 40.5}
with open('myJson.json','w')as f:
    json.dump(r.json(), f)
P = json.load(open('myJson.json'))
print(P)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8d8900524343> in <module>()
#       1 import json
# ----> 2 json.dumps(r.json())             # {"job": ["dev", "mgr"], "name": {"last": "Smith", "first": "Bob"}, "age": 40.5}
#       3 with open('myJson.json','w')as f:
#       4     json.dump(r.json(), f)
#       5 P = json.load(open('myJson.json'))
#
# NameError: name 'r' is not defined

# %%
import json
P = json.load(open('myJson.json'))

# %%
len(P["response"]["docs"])
P["response"]["docs"][0:2]
# Out:
# [{'_id': '58192bd57c459f606398d04b',
#   'abstract': 'Advocates for freedom of press denounce Montreal police force for its surveillance of reporter Patrick Lagace; spying was apparently prompted by media leaks from within department about internal investigation into corruption.',
#   'blog': [],
#   'byline': {'original': 'By IAN AUSTEN',
#    'person': [{'firstname': 'Ian',
#      'lastname': 'AUSTEN',
#      'organization': '',
#      'rank': 1,
#      'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'main': 'Montreal Police Face a Storm of Criticism Over Surveillance of a Journalist',
#    'print_headline': 'Montreal Police Face a Storm of Criticism Over Surveillance of a Journalist'},
#   'keywords': [{'is_major': 'Y',
#     'name': 'subject',
#     'rank': '1',
#     'value': 'Surveillance of Citizens by Government'},
#    {'is_major': 'Y',
#     'name': 'subject',
#     'rank': '2',
#     'value': 'Freedom of the Press'},
#    {'is_major': 'N',
#     'name': 'organizations',
#     'rank': '3',
#     'value': 'Supreme Court of Canada'},
#    {'is_major': 'Y',
#     'name': 'glocations',
#     'rank': '4',
#     'value': 'Montreal (Quebec)'},
#    {'is_major': 'N',
#     'name': 'glocations',
#     'rank': '5',
#     'value': 'Quebec Province (Canada)'},
#    {'is_major': 'Y',
#     'name': 'persons',
#     'rank': '6',
#     'value': 'Lagace, Patrick (1972- )'},
#    {'is_major': 'Y',
#     'name': 'subject',
#     'rank': '7',
#     'value': 'Police Brutality, Misconduct and Shootings'}],
#   'lead_paragraph': 'Investigators looking into corruption within the Montreal police force for almost six months focused their attention on a reporter who had no apparent connection to the case.',
#   'multimedia': [],
#   'news_desk': 'Foreign',
#   'print_page': '6',
#   'pub_date': '2016-11-01T23:57:01Z',
#   'section_name': 'World',
#   'slideshow_credits': None,
#   'snippet': 'Investigators looking into corruption within the Montreal police force for almost six months focused their attention on a reporter who had no apparent connection to the case....',
#   'source': 'The New York Times',
#   'subsection_name': 'Americas',
#   'type_of_material': 'News',
#   'web_url': 'http://www.nytimes.com/2016/11/02/world/americas/canada-patrick-lagace-montreal-police.html',
#   'word_count': '888'},
#  {'_id': '58192bcd7c459f606398d04a',
#   'abstract': 'Jurors send back three questions while deliberating case of Bridget Anne Kelly and Bill Baroni, former aides to New Jersey Gov Chris Christie accused of assisting him in 2013 plot to close lanes at George Washington Bridge; move suggests outcome to six-week trial may be divided. ',
#   'blog': [],
#   'byline': {'original': 'By KATE ZERNIKE',
#    'person': [{'firstname': 'Kate',
#      'lastname': 'ZERNIKE',
#      'organization': '',
#      'rank': 1,
#      'role': 'reported'}]},
#   'document_type': 'article',
#   'headline': {'main': 'Jurors’ Questions Hint at Division in Trial on Lane Closings',
#    'print_headline': 'Jurors’ Questions Hint at Split in Trial Over Lane Closings'},
#   'keywords': [{'is_major': 'N',
#     'name': 'subject',
#     'rank': '1',
#     'value': 'George Washington Bridge Scandal (2013)'},
#    {'is_major': 'Y', 'name': 'persons', 'rank': '2', 'value': 'Baroni, Bill'},
#    {'is_major': 'Y',
#     'name': 'persons',
#     'rank': '3',
#     'value': 'Kelly, Bridget Anne'},
#    {'is_major': 'N',
#     'name': 'persons',
#     'rank': '4',
#     'value': 'Wigenton, Susan D'},
#    {'is_major': 'Y',
#     'name': 'persons',
#     'rank': '5',
#     'value': 'Christie, Christopher J'},
#    {'is_major': 'N',
#     'name': 'glocations',
#     'rank': '6',
#     'value': 'Newark (NJ)'},
#    {'is_major': 'Y', 'name': 'glocations', 'rank': '7', 'value': 'New Jersey'},
#    {'is_major': 'Y',
#     'name': 'glocations',
#     'rank': '8',
#     'value': 'George Washington Bridge'}],
#   'lead_paragraph': 'Lawyers for Bridget Anne Kelly and Bill Baroni, former associates of Gov. Chris Christie of New Jersey, accused the judge of encouraging a guilty verdict.',
#   'multimedia': [{'height': 126,
#     'legacy': {'wide': 'images/2016/11/02/nyregion/02BRIDGEGATE1/02BRIDGEGATE1-thumbWide-v3.jpg',
#      'wideheight': '126',
#      'widewidth': '190'},
#     'subtype': 'wide',
#     'type': 'image',
#     'url': 'images/2016/11/02/nyregion/02BRIDGEGATE1/02BRIDGEGATE1-thumbWide-v3.jpg',
#     'width': 190},
#    {'height': 400,
#     'legacy': {'xlarge': 'images/2016/11/02/nyregion/02BRIDGEGATE1/02BRIDGEGATE1-articleLarge-v3.jpg',
#      'xlargeheight': '400',
#      'xlargewidth': '600'},
#     'subtype': 'xlarge',
#     'type': 'image',
#     'url': 'images/2016/11/02/nyregion/02BRIDGEGATE1/02BRIDGEGATE1-articleLarge-v3.jpg',
#     'width': 600},
#    {'height': 75,
#     'legacy': {'thumbnail': 'images/2016/11/02/nyregion/02BRIDGEGATE1/02BRIDGEGATE1-thumbStandard-v3.jpg',
#      'thumbnailheight': '75',
#      'thumbnailwidth': '75'},
#     'subtype': 'thumbnail',
#     'type': 'image',
#     'url': 'images/2016/11/02/nyregion/02BRIDGEGATE1/02BRIDGEGATE1-thumbStandard-v3.jpg',
#     'width': 75}],
#   'news_desk': 'Metro',
#   'print_page': '21',
#   'pub_date': '2016-11-01T23:56:57Z',
#   'section_name': 'N.Y. / Region',
#   'slideshow_credits': None,
#   'snippet': 'Lawyers for Bridget Anne Kelly and Bill Baroni, former associates of Gov. Chris Christie of New Jersey, accused the judge of encouraging a guilty verdict....',
#   'source': 'The New York Times',
#   'subsection_name': None,
#   'type_of_material': 'News',
#   'web_url': 'http://www.nytimes.com/2016/11/02/nyregion/jurors-questions-hint-at-division-in-trial-on-lane-closings.html',
#   'word_count': '615'}]

# %%
nyt_archive_key = "3106eb1daa574677845dd5391133c916"
h = requests.get("http://api.nytimes.com/svc/archive/v1/2015/4.json?api-key=" + nyt_archive_key)
i = requests.get("http://api.nytimes.com/svc/archive/v1/2015/5.json?api-key=" + nyt_archive_key)
j = requests.get("http://api.nytimes.com/svc/archive/v1/2015/6.json?api-key=" + nyt_archive_key)
q = requests.get("http://api.nytimes.com/svc/archive/v1/2015/7.json?api-key=" + nyt_archive_key)
l = requests.get("http://api.nytimes.com/svc/archive/v1/2015/8.json?api-key=" + nyt_archive_key)
m = requests.get("http://api.nytimes.com/svc/archive/v1/2015/9.json?api-key=" + nyt_archive_key)
n = requests.get("http://api.nytimes.com/svc/archive/v1/2015/10.json?api-key=" + nyt_archive_key)
o = requests.get("http://api.nytimes.com/svc/archive/v1/2015/11.json?api-key=" + nyt_archive_key)
p = requests.get("http://api.nytimes.com/svc/archive/v1/2015/12.json?api-key=" + nyt_archive_key)

# %%
import json

# %%
j.json()
# Out:
# {'copyright': 'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  'response': {'docs': [{'_id': '55660cfb38f0d86f0b8502d9',
#     'abstract': 'Study in journal PLoS One reports that violent wounds on 430,000-year-old skull found in cave in northern Spain may point to one of earliest murder cases on record.',
#     'blog': [],
#     'byline': {'original': 'By SINDYA N. BHANOO',
#      'person': [{'firstname': 'Sindya',
#        'lastname': 'BHANOO',
#        'middlename': 'N.',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Observatory',
#      'kicker': 'Observatory',
#      'main': 'Ancient Skull Suggests an Early Murder',
#      'print_headline': 'Fossils: Ancient Skull Points to an Early Murder'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Skull (Body Part)'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Archaeology and Anthropology'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Murders, Attempted Murders and Homicides'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'PLoS One (Journal)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '5',
#       'value': 'Science and Technology'}],
#     'lead_paragraph': 'The 430,000-year-old skull has two lesions above the left eye, either one of which might have been lethal, scientists report.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/05/28/science/02obs-murder/02obs-murder-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/05/28/science/02obs-murder/02obs-murder-thumbWide.jpg',
#       'width': 190},
#      {'height': 800,
#       'legacy': {'xlarge': 'images/2015/05/28/science/02obs-murder/02obs-murder-articleLarge.jpg',
#        'xlargeheight': '800',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/05/28/science/02obs-murder/02obs-murder-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/05/28/science/02obs-murder/02obs-murder-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/05/28/science/02obs-murder/02obs-murder-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Science',
#     'print_page': '2',
#     'pub_date': '2015-06-02T00:00:00Z',
#     'section_name': 'Science',
#     'slideshow_credits': None,
#     'snippet': 'The 430,000-year-old skull has two lesions above the left eye, either one of which might have been lethal, scientists report.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/02/science/ancient-skull-suggests-an-early-murder.html',
#     'word_count': '247'},
#    {'_id': '55663ef538f0d86f0b8503a7',
#     'abstract': 'Rapid pace of new archaeological and anthropological discoveries is giving rise to debate over pace of human evolution and diversity of early human family tree; study in journal Nature claiming jaw discovered in Ethiopia dating to 3.3 to 3.5 million years ago represents new human ancestor known as Australopithecus deyiremeda has been disputed by some scientists.',
#     'blog': [],
#     'byline': {'original': 'By CARL ZIMMER',
#      'person': [{'firstname': 'Carl',
#        'lastname': 'ZIMMER',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Matter',
#      'kicker': 'Matter',
#      'main': 'The Human Family Tree Bristles With New Branches',
#      'print_headline': 'Bones to Pick on Evolution'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Archaeology and Anthropology'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Nature (Journal)'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Evolution (Biology)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Australopithecines'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '5', 'value': 'Fossils'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '6',
#       'value': 'Paleontology'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '7',
#       'value': 'Science and Technology'}],
#     'lead_paragraph': 'Scientists reported finding another species of ancient hominid, Australopithecus deyiremeda, fanning debate over the pace of evolution and the number of human forebears.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/02/science/02MATTER/02MATTER-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/02/science/02MATTER/02MATTER-thumbWide.jpg',
#       'width': 190},
#      {'height': 399,
#       'legacy': {'xlarge': 'images/2015/06/02/science/02MATTER/02MATTER-articleLarge.jpg',
#        'xlargeheight': '399',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/02/science/02MATTER/02MATTER-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/02/science/02MATTER/02MATTER-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/02/science/02MATTER/02MATTER-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Science',
#     'print_page': '3',
#     'pub_date': '2015-06-02T00:00:00Z',
#     'section_name': 'Science',
#     'slideshow_credits': None,
#     'snippet': 'Scientists reported finding another species of ancient hominid, Australopithecus deyiremeda, fanning debate over the pace of evolution and the number of human forebears.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/02/science/adding-branches-to-the-human-family-tree.html',
#     'word_count': '1252'},
#    {'_id': '556760de38f0d8572a7b73ee',
#     'abstract': 'Robert S Wistrich, who spent four-decade scholarly career examining anti-Semitism, dies at age 70.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By SAM ROBERTS',
#      'person': [{'firstname': 'Sam',
#        'lastname': 'ROBERTS',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Robert S. Wistrich, Scholar of Anti-Semitism, Dies at 70',
#      'print_headline': 'Robert Wistrich, 70, Dies; Studied Anti-Semitism'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Deaths (Obituaries)'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '11',
#       'value': 'Krakow (Poland)'},
#      {'is_major': 'Y',
#       'name': 'persons',
#       'rank': '12',
#       'value': 'Wistrich, Robert S'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Jews and Judaism'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Anti-Semitism'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'War Crimes, Genocide and Crimes Against Humanity'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '5',
#       'value': 'Holocaust and the Nazi Era'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '6',
#       'value': 'Wiesenthal, Simon, Center'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '7',
#       'value': 'Stanford University'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '8',
#       'value': 'Herzl, Theodor'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '9',
#       'value': 'London (England)'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '10',
#       'value': 'Jerusalem (Israel)'}],
#     'lead_paragraph': 'The professor at Hebrew University in Jerusalem was the author or editor of 29 books, including the encyclopedic &#8220;Antisemitism: The Longest Hatred.&#8221;',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/02/world/02wistrich-obit/02wistrich-obit-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/02/world/02wistrich-obit/02wistrich-obit-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2015/06/02/world/02wistrich-obit/02wistrich-obit-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/02/world/02wistrich-obit/02wistrich-obit-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/02/world/02wistrich-obit/02wistrich-obit-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/02/world/02wistrich-obit/02wistrich-obit-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '18',
#     'pub_date': '2015-06-02T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'The professor at Hebrew University in Jerusalem was the author or editor of 29 books, including the encyclopedic &#8220;Antisemitism: The Longest Hatred.&#8221;',
#     'source': 'The New York Times',
#     'subsection_name': 'Europe',
#     'type_of_material': 'Obituary',
#     'web_url': 'http://www.nytimes.com/2015/05/28/world/europe/robert-s-wistrich-scholar-of-anti-semitism-dies-at-70.html',
#     'word_count': '976'},
#    {'_id': '55676ad438f0d8572a7b7417',
#     'abstract': "Study in journal Science finds that it may be possible to reduce people's racial and gender biases through technique called counterstereotype training, carried out in part while subject is asleep.",
#     'blog': [],
#     'byline': {'original': 'By SINDYA N. BHANOO',
#      'person': [{'firstname': 'Sindya',
#        'lastname': 'BHANOO',
#        'middlename': 'N.',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Observatory',
#      'kicker': 'Observatory',
#      'main': 'Race and Gender Biases Can be Reduced With Sleep Therapy, Study Finds',
#      'print_headline': 'Anthropology: Study Suggests Sleeping One’s Way Past Bias'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Discrimination'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '2', 'value': 'Sleep'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Science (Journal)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Race and Ethnicity'}],
#     'lead_paragraph': 'Participants were shown images of women alongside scientific words and black men with pleasant words and heard sounds that were played back during a 90-minute nap.',
#     'multimedia': [],
#     'news_desk': 'Science',
#     'print_page': '2',
#     'pub_date': '2015-06-02T00:00:00Z',
#     'section_name': 'Science',
#     'slideshow_credits': None,
#     'snippet': 'Participants were shown images of women alongside scientific words and black men with pleasant words and heard sounds that were played back during a 90-minute nap.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/02/science/race-and-gender-biases-can-be-reduced-with-sleep-therapy-study-finds.html',
#     'word_count': '174'},
#    {'_id': '5568a4b838f0d87c79ae5f32',
#     'abstract': 'Atlanta judge rules that Atlanta warehouse owner Atlas Logistics Group Retail Services violated Genetic Information Nondiscrimination Act when it tested DNA of two men to determine if they had been leaving piles of feces around workplace; decision in unusual case shows scope of law goes beyond its original intent.',
#     'blog': [],
#     'byline': {'original': 'By GINA KOLATA',
#      'person': [{'firstname': 'Gina',
#        'lastname': 'KOLATA',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': '‘Devious Defecator’ Case Tests Genetics Law',
#      'print_headline': 'Strange Violation of a Genetics Law'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'DNA (Deoxyribonucleic Acid)'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Atlas Logistics Group Retail Services'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '3', 'value': 'Feces'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Discrimination'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '5',
#       'value': 'Genetics and Heredity'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '6',
#       'value': 'Suits and Litigation (Civil)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '8',
#       'value': 'Law and Legislation'}],
#     'lead_paragraph': 'A company’s use of DNA tests to investigate employee wrongdoing ran afoul of a federal antidiscrimination law.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/05/30/science/02genetics1/02genetics1-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/05/30/science/02genetics1/02genetics1-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2015/05/30/science/02genetics1/02genetics1-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/05/30/science/02genetics1/02genetics1-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/05/30/science/02genetics1/02genetics1-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/05/30/science/02genetics1/02genetics1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Science',
#     'print_page': '6',
#     'pub_date': '2015-06-02T00:00:00Z',
#     'section_name': 'Health',
#     'slideshow_credits': None,
#     'snippet': 'A company’s use of DNA tests to investigate employee wrongdoing ran afoul of a federal antidiscrimination law.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/02/health/devious-defecator-case-tests-genetics-law.html',
#     'word_count': '1253'},
#    {'_id': '5568cfe138f0d87c79ae5fc7',
#     'abstract': "Mysterious disease has been killing off world's population of saigas, type of antelope found in Central Asia, claiming more than a third of 250,000 remaining animals in span of few weeks; endangered population had been rebounding from poaching, but unexplained deaths could undo years of conservation efforts even as biologists struggle to discover cause.",
#     'blog': [],
#     'byline': {'original': 'By CARL ZIMMER',
#      'person': [{'firstname': 'Carl',
#        'lastname': 'ZIMMER',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Death on the Steppes: Mystery Disease Kills Saigas',
#      'print_headline': 'Death on the Steppes'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Saigas'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Endangered and Extinct Species'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '3',
#       'value': 'Central Asia'}],
#     'lead_paragraph': 'In the past two weeks, more than a third of all saigas have been killed, conservationists have found. The cause of the outbreak is unknown.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/05/30/science/02antelope-a/02antelope-a-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/05/30/science/02antelope-a/02antelope-a-thumbWide.jpg',
#       'width': 190},
#      {'height': 371,
#       'legacy': {'xlarge': 'images/2015/05/30/science/02antelope-a/02antelope-a-articleLarge.jpg',
#        'xlargeheight': '371',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/05/30/science/02antelope-a/02antelope-a-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/05/30/science/02antelope-a/02antelope-a-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/05/30/science/02antelope-a/02antelope-a-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Science',
#     'print_page': '1',
#     'pub_date': '2015-06-02T00:00:00Z',
#     'section_name': 'Science',
#     'slideshow_credits': None,
#     'snippet': 'In the past two weeks, more than a third of all saigas have been killed, conservationists have found. The cause of the outbreak is unknown.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/02/science/saiga-antelope-mystery-disease-die-off.html',
#     'word_count': '1000'},
#    {'_id': '556ad4b138f0d87ed70a531a',
#     'abstract': "Spike Lee movie Chir-Raq is set to begin filming in Chicago's South Side, area plagued by crime and gang warfare; many residents and politicians have taken issue with title, which references city's gun violence, saying it casts Chicago in negative light.",
#     'blog': [],
#     'byline': {'original': 'By JULIE BOSMAN',
#      'person': [{'firstname': 'Julie',
#        'lastname': 'BOSMAN',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'For Some in Chicago, Spike Lee’s ‘Chiraq’ Has a Title That Rankles',
#      'print_headline': 'For Some in Chicago, a Movie Title That Rankles'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Movies'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '2',
#       'value': 'Chicago (Ill)'},
#      {'is_major': 'Y', 'name': 'persons', 'rank': '3', 'value': 'Lee, Spike'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Murders, Attempted Murders and Homicides'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '5', 'value': 'Gangs'}],
#     'lead_paragraph': 'City officials and some residents object to the film’s name, a reference to Chicago’s gun violence, but others say a movie title is not the problem.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/01/us/01chiraq-JP/01chiraq-JP-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/01/us/01chiraq-JP/01chiraq-JP-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2015/06/01/us/01chiraq-JP/01chiraq-JP-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/01/us/01chiraq-JP/01chiraq-JP-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/01/us/01chiraq-JP/01chiraq-JP-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/01/us/01chiraq-JP/01chiraq-JP-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'National',
#     'print_page': '10',
#     'pub_date': '2015-06-01T00:00:00Z',
#     'section_name': 'U.S.',
#     'slideshow_credits': None,
#     'snippet': 'City officials and some residents object to the film’s name, a reference to Chicago’s gun violence, but others say a movie title is not the problem.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/us/spike-lee-comes-to-film-chiraq-unsettling-some-chicagoans.html',
#     'word_count': '1074'},
#    {'_id': '556ae24a38f0d87ed70a5327',
#     'abstract': None,
#     'blog': [],
#     'byline': {'original': 'By HUGO DIXON',
#      'person': [{'firstname': 'Hugo',
#        'lastname': 'DIXON',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Political Economy',
#      'kicker': 'Political Economy',
#      'main': 'Ultimatums Will Only Aggravate Greece’s Problems',
#      'print_headline': 'Ultimatums Will Only Aggravate Greece’s Problems'},
#     'keywords': [{'is_major': 'N',
#       'name': 'glocations',
#       'rank': '1',
#       'value': 'Greece'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'European Sovereign Debt Crisis (2010- )'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '3',
#       'value': 'Tsipras, Alexis'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Eurozone'}],
#     'lead_paragraph': 'Greece will never be a successful modern country until it makes rules for itself and then sticks to them.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/01/business/01dixon/01dixon-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/01/business/01dixon/01dixon-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2015/06/01/business/01dixon/01dixon-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/01/business/01dixon/01dixon-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/01/business/01dixon/01dixon-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/01/business/01dixon/01dixon-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Business',
#     'print_page': None,
#     'pub_date': '2015-06-01T12:30:00Z',
#     'section_name': 'Business Day',
#     'slideshow_credits': None,
#     'snippet': 'Greece will never be a successful modern country until it makes rules for itself and then sticks to them.',
#     'source': 'The New York Times',
#     'subsection_name': 'International Business',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/business/international/ultimatums-will-only-aggravate-greeces-problems.html',
#     'word_count': '821'},
#    {'_id': '556ae2a138f0d87ed70a5328',
#     'abstract': None,
#     'blog': [],
#     'byline': {'original': 'By ROB HUGHES',
#      'person': [{'firstname': 'Rob',
#        'lastname': 'HUGHES',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Global Soccer',
#      'main': 'Messi and Arsenal Remind Us What Soccer Is All About',
#      'print_headline': 'Messi and Arsenal Remind Us What Soccer Is All About'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Soccer'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '11',
#       'value': 'Juventus (Soccer Team)'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '12',
#       'value': 'Enrique, Luis (1970- )'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '13',
#       'value': 'Walcott, Theo'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '14',
#       'value': 'Klopp, Jurgen Norbert (1967- )'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '15',
#       'value': 'Wenger, Arsene'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Barcelona (Soccer Team)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Wolfsburg (Soccer Team)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Arsenal (Soccer Team)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '5',
#       'value': 'Football Association Cup (Soccer)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '6',
#       'value': 'Paris St-Germain FC (Soccer Team)'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '7',
#       'value': 'Messi, Lionel'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '8',
#       'value': 'UEFA Champions League (Soccer)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '9',
#       'value': 'Aston Villa (Soccer Team)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '10',
#       'value': 'Borussia Dortmund (Soccer Team)'}],
#     'lead_paragraph': 'After the ugly circus and arrests in Zurich, domestic cup finals in four countries helped showcase why soccer is still called the beautiful game.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/01/sports/01hughes/01hughes-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/01/sports/01hughes/01hughes-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2015/06/01/sports/01hughes/01hughes-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/01/sports/01hughes/01hughes-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/01/sports/01hughes/01hughes-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/01/sports/01hughes/01hughes-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Sports',
#     'print_page': None,
#     'pub_date': '2015-06-01T14:00:00Z',
#     'section_name': 'Sports',
#     'slideshow_credits': None,
#     'snippet': 'After the ugly circus and arrests in Zurich, domestic cup finals in four countries helped showcase why soccer is still called the beautiful game.',
#     'source': 'The New York Times',
#     'subsection_name': 'Soccer',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/sports/soccer/messi-and-arsenal-remind-us-what-soccer-is-all-about.html',
#     'word_count': '956'},
#    {'_id': '556ae4e338f0d87ed70a532a',
#     'abstract': 'Secretary of State John Kerry will cut short his European trip after breaking leg in bicycle accident; will return for medical treatment in Boston.',
#     'blog': [],
#     'byline': {'original': 'By MICHAEL R. GORDON',
#      'person': [{'firstname': 'Michael',
#        'lastname': 'GORDON',
#        'middlename': 'R.',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'John Kerry Cuts Europe Trip Short After Breaking Leg in Bicycle Accident',
#      'print_headline': 'Kerry Cuts European Trip Short After Breaking Leg'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'persons',
#       'rank': '1',
#       'value': 'Kerry, John'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Bicycles and Bicycling'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Accidents and Safety'},
#      {'is_major': 'N', 'name': 'glocations', 'rank': '4', 'value': 'France'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '5',
#       'value': 'Geneva (Switzerland)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '6',
#       'value': 'United States International Relations'}],
#     'lead_paragraph': 'The secretary of state struck a curb while he was cycling near Scionzier, France, and was returning to Boston for treatment.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/05/19/world/01kerry-1/18watching-kerry03-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/05/19/world/01kerry-1/18watching-kerry03-thumbWide.jpg',
#       'width': 190},
#      {'height': 426,
#       'legacy': {'xlarge': 'images/2015/05/19/world/01kerry-1/18watching-kerry03-articleLarge.jpg',
#        'xlargeheight': '426',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/05/19/world/01kerry-1/18watching-kerry03-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/05/19/world/01kerry-1/18watching-kerry03-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/05/19/world/01kerry-1/18watching-kerry03-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '3',
#     'pub_date': '2015-06-01T00:00:00Z',
#     'section_name': 'U.S.',
#     'slideshow_credits': None,
#     'snippet': 'The secretary of state struck a curb while he was cycling near Scionzier, France, and was returning to Boston for treatment.',
#     'source': 'The New York Times',
#     'subsection_name': 'Politics',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/us/politics/secretary-of-state-john-kerry-flown-to-swiss-hospital-after-bike-crash.html',
#     'word_count': '627'},
#    {'_id': '556af0d238f0d87ed70a5338',
#     'abstract': 'Doctors are underscoring need for test that can determine whether expensive immune-boosting drugs like Opdivo and Yervoy will work on cancer patients in advance, as drugs help only minority of patients, but work exceedingly well; challenges of creating test are both ethical and scientific; importance of test has been laid out in study published in New England Journal of Medicine.',
#     'blog': [],
#     'byline': {'original': 'By ANDREW POLLACK',
#      'person': [{'firstname': 'Andrew',
#        'lastname': 'POLLACK',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Doctors Seek Test for Deploying New Life-Extending Cancer Drugs',
#      'print_headline': 'Specialists Seeking Tests for Deploying New Life-Extending Cancer Drugs'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Drugs (Pharmaceuticals)'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '2', 'value': 'Cancer'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Tests (Medical)'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'New England Journal of Medicine'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '5', 'value': 'Lung Cancer'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '6',
#       'value': 'Immune System'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '7',
#       'value': 'Memorial Sloan-Kettering Cancer Center'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '8', 'value': 'Tumors'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '9', 'value': 'Melanomas'}],
#     'lead_paragraph': 'Identifying which patients are likely to benefit from expensive treatments such as Opdivo, Yervoy and Keytruda could save money and prevent side effects.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/05/31/business/01SKIN-web/01SKIN-web-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/05/31/business/01SKIN-web/01SKIN-web-thumbWide.jpg',
#       'width': 190},
#      {'height': 401,
#       'legacy': {'xlarge': 'images/2015/05/31/business/01SKIN-web/01SKIN-web-articleLarge.jpg',
#        'xlargeheight': '401',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/05/31/business/01SKIN-web/01SKIN-web-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/05/31/business/01SKIN-web/01SKIN-web-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/05/31/business/01SKIN-web/01SKIN-web-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Business',
#     'print_page': '3',
#     'pub_date': '2015-06-01T00:00:00Z',
#     'section_name': 'Business Day',
#     'slideshow_credits': None,
#     'snippet': 'Identifying which patients are likely to benefit from expensive treatments such as Opdivo, Yervoy and Keytruda could save money and prevent side effects.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/business/doctors-seek-test-for-deploying-new-life-extending-cancer-drugs.html',
#     'word_count': '1097'},
#    {'_id': '556aff7538f0d87ed70a5346',
#     'abstract': "Adm Sun Jianguo of China, speaking at security forum in Singapore, says Beijing could create air defense zone above disputed areas of South China if it assessed large enough threat; action, if carried out, would further cement China's military presence in the waters, and be perceived by United States and Southeast Asian countries as major provocation.",
#     'blog': [],
#     'byline': {'contributor': 'Matthew Rosenberg contributed reporting from Haiphong, Vietnam. Yufan Huang contributed research.',
#      'original': 'By EDWARD WONG',
#      'person': [{'firstname': 'Edward',
#        'lastname': 'WONG',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'China Says It Could Set Up Air Defense Zone in South China Sea',
#      'print_headline': 'China Says It Could Add Defense Zone Over Disputed Waters '},
#     'keywords': [{'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '1',
#       'value': 'China'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '2',
#       'value': 'South China Sea'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Defense and Military Forces'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '4',
#       'value': "People's Liberation Army (China)"},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '5',
#       'value': 'International Relations'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '6',
#       'value': 'United States'}],
#     'lead_paragraph': 'A Chinese admiral told a security forum in Singapore that Beijing could create a zone above disputed areas if it felt it was facing a large enough threat.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/01/world/CHINA/CHINA-thumbWide-v2.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/CHINA/CHINA-thumbWide-v2.jpg',
#       'width': 190},
#      {'height': 384,
#       'legacy': {'xlarge': 'images/2015/06/01/world/CHINA/CHINA-articleLarge.jpg',
#        'xlargeheight': '384',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/CHINA/CHINA-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/01/world/CHINA/CHINA-thumbStandard-v2.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/CHINA/CHINA-thumbStandard-v2.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '8',
#     'pub_date': '2015-06-01T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'A Chinese admiral told a security forum in Singapore that Beijing could create a zone above disputed areas if it felt it was facing a large enough threat.',
#     'source': 'The New York Times',
#     'subsection_name': 'Asia Pacific',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/world/asia/china-says-it-could-set-up-air-defense-zone-in-south-china-sea.html',
#     'word_count': '1281'},
#    {'_id': '556b06eb38f0d87ed70a534c',
#     'abstract': "Local officials in Libya report that Islamic State has made further gains there, expanding its territory and driving out militia from city Misurata; Western officials are concerned by group's advances, given how close country is to Europe.",
#     'blog': [],
#     'byline': {'original': 'By SULIMAN ALI ZWAY and DAVID D. KIRKPATRICK',
#      'person': [{'firstname': 'Suliman',
#        'lastname': 'ZWAY',
#        'middlename': 'Ali',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'},
#       {'firstname': 'David',
#        'organization': '',
#        'rank': 2,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Western Officials Alarmed as ISIS Expands Territory in Libya',
#      'print_headline': 'Western Officials Alarmed by ISIS’ Advances in Libya'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '1',
#       'value': 'Islamic State in Iraq and Syria (ISIS)'},
#      {'is_major': 'Y', 'name': 'glocations', 'rank': '2', 'value': 'Libya'},
#      {'is_major': 'N', 'name': 'glocations', 'rank': '3', 'value': 'Europe'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '4',
#       'value': 'Misurata (Libya)'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '5', 'value': 'Terrorism'}],
#     'lead_paragraph': 'The group’s expansion in Libya gives it an alternative base of operations as it appears to be gaining ground in Palmyra in Syria and in Ramadi in Iraq.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/01/world/LIBYA/LIBYA-thumbWide-v2.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/LIBYA/LIBYA-thumbWide-v2.jpg',
#       'width': 190},
#      {'height': 391,
#       'legacy': {'xlarge': 'images/2015/06/01/world/LIBYA/LIBYA-articleLarge.jpg',
#        'xlargeheight': '391',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/LIBYA/LIBYA-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/01/world/LIBYA/LIBYA-thumbStandard-v3.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/LIBYA/LIBYA-thumbStandard-v3.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '9',
#     'pub_date': '2015-06-01T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'The group’s expansion in Libya gives it an alternative base of operations as it appears to be gaining ground in Palmyra in Syria and in Ramadi in Iraq.',
#     'source': 'The New York Times',
#     'subsection_name': 'Middle East',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/world/africa/western-officials-alarmed-as-islamic-state-expands-territory-in-libya.html',
#     'word_count': '415'},
#    {'_id': '556b09f038f0d87ed70a534e',
#     'abstract': "Research coalition led by Smithsonian's National Museum of African American History and Culture are set to announce discovery of wreck of ship Sao Jose Paquete Africa, marking first recovery of slaving ship that went down with slaves aboard; Portuguese vessel met its doom near Cape Town, South Africa, in 1794, claiming lives of estimated 212 slaves out of 400 to 500 that had been shackled under brutal conditions in its hull.",
#     'blog': [],
#     'byline': {'contributor': 'Jada F. Smith contributed reporting.',
#      'original': 'By HELENE COOPER',
#      'person': [{'firstname': 'Helene',
#        'lastname': 'COOPER',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Grim History Traced in Sunken Slave Ship Found Off South Africa',
#      'print_headline': 'Sea Yields Slaves&#8217; Grim Fate '},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Slavery (Historical)'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '11',
#       'value': 'South Africa'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Shipwrecks (Historic)'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '3',
#       'value': 'Cape Town (South Africa)'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'National Museum of African American History and Culture'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '5', 'value': 'Blacks'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '6',
#       'value': 'Smithsonian Institution'},
#      {'is_major': 'N', 'name': 'glocations', 'rank': '7', 'value': 'Portugal'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '8', 'value': 'Museums'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '9',
#       'value': 'Museum of African-American History'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '10',
#       'value': 'Dutch East India Co'}],
#     'lead_paragraph': 'The Smithsonian will announce Tuesday that the wreckage of a vessel that sank in 1794 has been found, the first time a slaving ship that went down with slaves aboard has been recovered.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/01/world/01SLAVESHIP1/01SLAVESHIP1-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/01SLAVESHIP1/01SLAVESHIP1-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2015/06/01/world/01SLAVESHIP1/01SLAVESHIP1-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/01SLAVESHIP1/01SLAVESHIP1-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/01/world/01SLAVESHIP1/01SLAVESHIP1-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/01/world/01SLAVESHIP1/01SLAVESHIP1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '1',
#     'pub_date': '2015-06-01T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'The Smithsonian will announce Tuesday that the wreckage of a vessel that sank in 1794 has been found, the first time a slaving ship that went down with slaves aboard has been recovered.',
#     'source': 'The New York Times',
#     'subsection_name': 'Africa',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/world/africa/tortuous-history-traced-in-sunken-slave-ship-found-off-south-africa.html',
#     'word_count': '1815'},
#    {'_id': '556b2b5338f0d87ed70a5387',
#     'abstract': None,
#     'blog': [],
#     'byline': {'original': 'By ALBERT R. HUNT | BLOOMBERG VIEW',
#      'person': [{'firstname': 'Albert',
#        'lastname': 'HUNT',
#        'middlename': 'R.',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Letter From Washington',
#      'kicker': 'Letter From Washington',
#      'main': 'Tough Talk, but Little in Way of Policy From Republicans',
#      'print_headline': 'Tough Talk, but Little in Way of Policy From Republicans'},
#     'keywords': [{'is_major': 'N',
#       'name': 'organizations',
#       'rank': '1',
#       'value': 'Republican Party'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '2',
#       'value': 'Graham, Lindsey'},
#      {'is_major': 'N', 'name': 'persons', 'rank': '3', 'value': 'Paul, Rand'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Presidential Election of 2016'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '5',
#       'value': 'Putin, Vladimir V'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '6',
#       'value': 'Islamic State in Iraq and Syria (ISIS)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '7',
#       'value': 'United States International Relations'}],
#     'lead_paragraph': 'The only potential Republican candidate whose tough words on the Islamic State are matched by policy prescriptions is Senator Lindsey Graham.',
#     'multimedia': [],
#     'news_desk': 'Foreign',
#     'print_page': None,
#     'pub_date': '2015-06-01T20:40:00Z',
#     'section_name': 'U.S.',
#     'slideshow_credits': None,
#     'snippet': 'The only potential Republican candidate whose tough words on the Islamic State are matched by policy prescriptions is Senator Lindsey Graham.',
#     'source': 'The New York Times',
#     'subsection_name': 'Politics',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/01/us/politics/tough-talk-but-little-in-way-of-policy-from-republicans.html',
#     'word_count': '680'},
#    {'_id': '556b2d0638f0d87ed70a538a',
#     'abstract': 'Heating and air-conditioning unit comes untethered from crane in Midtown Manhattan, lightly injuring seven people after it crashes thirty stories to the ground; observers say incident could have been far worse had it occurred amid weekday foot traffic.',
#     'blog': [],
#     'byline': {'original': 'By ASHLEY SOUTHALL',
#      'person': [{'firstname': 'Ashley',
#        'lastname': 'SOUTHALL',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Crane Accident in Midtown Manhattan Injures 7 and Damages Buildings',
#      'print_headline': 'Crane Collapse Causes Heavy Equipment to Fall, Injuring 7 in Midtown Manhattan'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Accidents and Safety'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '2',
#       'value': 'Midtown Area (Manhattan, NY)'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Derricks and Cranes'}],
#     'lead_paragraph': 'The crane was lifting a heating and air-conditioning unit to the top of 261 Madison Avenue when it came untethered, sending the unit falling 30 stories to the ground, the Fire Department said.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/01/nyregion/01CRANE1web/01CRANE1web-thumbWide.jpg',
# ...
#     'snippet': 'A New York suit maker discusses his trade and the latest men’s fashions.',
#     'source': 'The New York Times',
#     'subsection_name': 'Men’s Style',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/05/fashion/mens-style/vahram-mateosian-owner-and-operator-of-mr-ned.html',
#     'word_count': '319'},
#    {'_id': '5570787538f0d80a7d1ade19',
#     'abstract': "DealBook Online; British government will sell its remaining stake in the Royal Mail, operator of Britain's postal service, as part of debt-reduction plan; 30 percent stake is worth roughly 1.5 billion pounds, or $2.3 billion.",
#     'blog': [],
#     'byline': {'original': 'By CHAD BRAY',
#      'person': [{'firstname': 'Chad',
#        'lastname': 'BRAY',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'British Government to Sell Remaining Stake in Royal Mail',
#      'print_headline': 'Royal Mail Sale'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '1',
#       'value': 'Great Britain'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Royal Mail Holdings PLC'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Initial Public Offerings'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '4',
#       'value': 'Osborne, George'}],
#     'lead_paragraph': 'The move comes nearly two years after an initial public offering for the operator of Britain’s postal service and follows criticism of its pricing.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/04/business/dealbook/dbpix-mail/dbpix-mail-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/04/business/dealbook/dbpix-mail/dbpix-mail-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2015/06/04/business/dealbook/dbpix-mail/dbpix-mail-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/04/business/dealbook/dbpix-mail/dbpix-mail-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/04/business/dealbook/dbpix-mail/dbpix-mail-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/04/business/dealbook/dbpix-mail/dbpix-mail-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Business',
#     'print_page': '5',
#     'pub_date': '2015-06-05T00:00:00Z',
#     'section_name': 'Business Day',
#     'slideshow_credits': None,
#     'snippet': 'The move comes nearly two years after an initial public offering for the operator of Britain’s postal service and follows criticism of its pricing.',
#     'source': 'The New York Times',
#     'subsection_name': 'DealBook',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/05/business/dealbook/british-government-to-sell-remaining-stake-in-royal-mail.html',
#     'word_count': '341'},
#    {'_id': '5570790a38f0d80a7d1ade1d',
#     'abstract': "Michael Kimmelman Critic's Notebook applauds Frick Collection devotees and de Blasio administration for stopping museum from razing unique Russell Page-designed garden in order to build ungainly six-story edition and forcing them to consider alternative architectural options.",
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By MICHAEL KIMMELMAN',
#      'person': [{'firstname': 'Michael',
#        'lastname': 'KIMMELMAN',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Critic’s Notebook: Frick Collection Spares a Prized Garden',
#      'print_headline': 'The Frick Spares a Prized Garden'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '1',
#       'value': 'Frick Collection'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Historic Buildings and Sites'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Landmarks Preservation Commission'}],
#     'lead_paragraph': 'The Frick, nudged back to the drawing board by City Hall, has a chance to devise a creative plan for expansion that will leave its Russell Page-designed garden intact.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/04/nyregion/04FRICK2city/04FRICK2city-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/04/nyregion/04FRICK2city/04FRICK2city-thumbWide.jpg',
#       'width': 190},
#      {'height': 296,
#       'legacy': {'xlarge': 'images/2015/06/04/nyregion/04FRICK2city/04FRICK2city-articleLarge.jpg',
#        'xlargeheight': '296',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/04/nyregion/04FRICK2city/04FRICK2city-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/04/nyregion/04FRICK2city/04FRICK2city-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/04/nyregion/04FRICK2city/04FRICK2city-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Weekend',
#     'print_page': '17',
#     'pub_date': '2015-06-05T00:00:00Z',
#     'section_name': 'Arts',
#     'slideshow_credits': None,
#     'snippet': 'The Frick, nudged back to the drawing board by City Hall, has a chance to devise a creative plan for expansion that will leave its Russell Page-designed garden intact.',
#     'source': 'The New York Times',
#     'subsection_name': 'Art & Design',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/05/arts/design/critics-notebook-frick-collection-returns-to-square-one-a-prized-garden-intact.html',
#     'word_count': '829'},
#    {'_id': '55707d3938f0d80a7d1ade32',
#     'abstract': "Human rights groups are concerned about Pakistan's quick pace in executing death row prisoners since December 2014 removal of six-year moratorium on death penalty; figure estimated to be between 135-150 executions so far in 2015 is higher than any full year in a decade.",
#     'blog': [],
#     'byline': {'original': 'By SALMAN MASOOD',
#      'person': [{'firstname': 'Salman',
#        'lastname': 'MASOOD',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Pakistan’s Pace of Executions Alarms Rights Groups',
#      'print_headline': 'World Briefing | Asia; Pakistan: Pace of Executions Accelerates'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '1',
#       'value': 'Pakistan'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Capital Punishment'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Human Rights and Human Rights Violations'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Human Rights Commission of Pakistan'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '5',
#       'value': 'Hussain, Shafqat'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '6',
#       'value': 'Reprieve'}],
#     'lead_paragraph': 'A rights group estimated that at least 135 executions have already taken place this year since the lifting of a moratorium on the death penalty in December.',
#     'multimedia': [],
#     'news_desk': 'Foreign',
#     'print_page': '6',
#     'pub_date': '2015-06-05T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'A rights group estimated that at least 135 executions have already taken place this year since the lifting of a moratorium on the death penalty in December.',
#     'source': 'The New York Times',
#     'subsection_name': 'Asia Pacific',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/05/world/asia/pakistans-pace-of-executions-alarms-rights-groups.html',
#     'word_count': '365'},
#    {'_id': '55707f2e38f0d80a7d1ade40',
#     'abstract': 'Announcement by Fox News and CNN that they will limit first two major debates to candidates within top 10 of national voter polls has alarmed many candidates in crowded Republican presidential field; lesser-known candidates in particular are under tremendous pressure to extend their appeal ahead of debates.',
#     'blog': [],
#     'byline': {'original': 'By MAGGIE HABERMAN and JEREMY W. PETERS',
#      'person': [{'firstname': 'Maggie',
#        'lastname': 'HABERMAN',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'},
#       {'firstname': 'Jeremy',
#        'lastname': 'PETERS',
#        'middlename': 'W.',
#        'organization': '',
#        'rank': 2,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'As Republican Debates Near, Candidates Vie to Make Cut  ',
#      'print_headline': 'Plan to Thin Debate Field Stirs Anxiety Into G.O.P.'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Presidential Election of 2016'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '11',
#       'value': 'Santorum, Rick'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '12',
#       'value': 'Rubio, Marco'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Debates (Political)'},
#      {'is_major': 'Y', 'name': 'organizations', 'rank': '3', 'value': 'CNN'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Fox News Channel'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '5',
#       'value': 'Republican Party'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '6',
#       'value': 'Christie, Christopher J'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '7',
#       'value': 'Fiorina, Carleton S'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '8',
#       'value': 'Jindal, Bobby'},
#      {'is_major': 'N', 'name': 'persons', 'rank': '9', 'value': 'Perry, Rick'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '10',
#       'value': 'Walker, Scott K'}],
#     'lead_paragraph': 'Fox News and CNN say only candidates polling in the top 10 will be invited to their debates, sending waves of anxiety into the campaigns.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/05/us/05DEBATEweb/05DEBATEweb-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/05/us/05DEBATEweb/05DEBATEweb-thumbWide.jpg',
#       'width': 190},
#      {'height': 410,
#       'legacy': {'xlarge': 'images/2015/06/05/us/05DEBATEweb/05DEBATEweb-articleLarge.jpg',
#        'xlargeheight': '410',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/05/us/05DEBATEweb/05DEBATEweb-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/05/us/05DEBATEweb/05DEBATEweb-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/05/us/05DEBATEweb/05DEBATEweb-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'National',
#     'print_page': '17',
#     'pub_date': '2015-06-05T00:00:00Z',
#     'section_name': 'U.S.',
#     'slideshow_credits': None,
#     'snippet': 'Fox News and CNN say only candidates polling in the top 10 will be invited to their debates, sending waves of anxiety into the campaigns.',
#     'source': 'The New York Times',
#     'subsection_name': 'Politics',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/05/us/republican-presidential-candidates-fight-to-make-cnn-fox-debate-cut.html',
#     'word_count': '1238'},
#    {'_id': '5570811d38f0d80a7d1ade46',
#     'abstract': "Stephane Richard, chief executive of French multinational telecommunications corporation Orange, says he would leave Israeli market if it were not for potential legal and financial penalties, setting off furor in Israel; boycott Israel movement has been growing since failed Palestinian bid to oust Israel from FIFA, soccer's global governing body.",
#     'blog': [],
#     'byline': {'contributor': 'Myra Noveck contributed reporting.',
#      'original': 'By ISABEL KERSHNER',
#      'person': [{'firstname': 'Isabel',
#        'lastname': 'KERSHNER',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'French Telecom Executive’s Remarks on Israel Incite Furor',
#      'print_headline': 'A French C.E.O.&#8217;s Remarks on Leaving Israel Incite a Furor'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Palestinians'},
#      {'is_major': 'Y', 'name': 'glocations', 'rank': '2', 'value': 'Israel'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '3', 'value': 'Boycotts'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Orange PLC'},
#      {'is_major': 'Y',
#       'name': 'persons',
#       'rank': '5',
#       'value': 'Richard, Stephane'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '6', 'value': 'Soccer'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '7',
#       'value': 'International Federation of Association Football (FIFA)'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '8',
#       'value': 'Telephones and Telecommunications'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '9',
#       'value': 'Cellular Telephones'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '10',
#       'value': 'Boycott, Divestment and Sanctions (BDS)'}],
#     'lead_paragraph': 'The executive of Orange, licenser to a major Israeli cellphone provider, hit a nerve in Israel, where angst over a pro-Palestinian boycott is growing.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2015/06/05/world/BOYCOTT1/BOYCOTT1-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2015/06/05/world/BOYCOTT1/BOYCOTT1-thumbWide.jpg',
#       'width': 190},
#      {'height': 399,
#       'legacy': {'xlarge': 'images/2015/06/05/world/BOYCOTT1/BOYCOTT1-articleLarge.jpg',
#        'xlargeheight': '399',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2015/06/05/world/BOYCOTT1/BOYCOTT1-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2015/06/05/world/BOYCOTT1/BOYCOTT1-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2015/06/05/world/BOYCOTT1/BOYCOTT1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '11',
#     'pub_date': '2015-06-05T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'The executive of Orange, licenser to a major Israeli cellphone provider, hit a nerve in Israel, where angst over a pro-Palestinian boycott is growing.',
#     'source': 'The New York Times',
#     'subsection_name': 'Middle East',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2015/06/05/world/middleeast/french-telecom-executives-remarks-on-israel-incite-furor.html',
#     'word_count': '1379'},
#    ...],
#   'meta': {'hits': 7146}}}

# %%
with open('myJson3.json','w')as f8:
    json.dump(h.json(), f8)
with open('myJson4.json','w')as f9:
    json.dump(i.json(), f9)
with open('myJson5.json','w')as f10:
    json.dump(j.json(), f10)
with open('myJson6.json','w')as f11:
    json.dump(q.json(), f11)
with open('myJson7.json','w')as f12:
    json.dump(l.json(), f12)
with open('myJson8.json','w')as f13:
    json.dump(m.json(), f13)
with open('myJson9.json','w')as f14:
    json.dump(n.json(), f14)
with open('myJson10.json','w')as f15:
    json.dump(o.json(), f15)
with open('myJson11.json','w')as f16:
    json.dump(p.json(), f16)

# %% [markdown]
# # Article Search API

# %%
http://api.nytimes.com/svc/search/v2/articlesearch.json?q=new+york+times&page=2&sort=oldest&api-key=####
# Out:
# '\nprint(22+33)\n'

# %%
http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=romney&facet_field=day_of_week&begin_date=20120101&end_date=20120101&api-key=####
# Out:
#   File "<ipython-input-6-9baf0f4e8131>", line 1
#     """"
#         ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
nyt_search_key = "eb0b0061921046d8922ddcd90f31df1e"
